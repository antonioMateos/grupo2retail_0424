# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.statespace.sarimax import SARIMAX
import xgboost as xgb
import warnings

warnings.filterwarnings('ignore')
pd.set_option('display.float_format', lambda x: '%.2f' % x)
pd.set_option('display.max_columns',100)
pd.set_option('display.width',100)
pd.set_option('display.max_colwidth',100)

tiendas_SARIMAX=['Brooklyn','Midtown_Village','Roxbury']
tiendas_XGB_24_L30 = ['Back_Bay','Yorktown']
tiendas_XGB_SC_L30 = ['Harlem','Total Tiendas']
tiendas_XGB_SC_L365 = ['Greenwich_Village','Queen_Village','South_End','Tribeca']
tiendas_XGB = tiendas_XGB_24_L30 + tiendas_XGB_SC_L30 + tiendas_XGB_SC_L365
df_hp = pd.read_csv("hiperparametros XGBOOST.csv",delimiter=";")
df_eventos = pd.read_csv("daily_calendar_with_events.csv")
df_eventos = df_eventos.dropna(subset=['event'])
df_venart = pd.read_csv("ventas por articulo.csv")
df_venart['fecha'] = pd.to_datetime(df_venart['fecha'], format = '%Y-%m-%d')

# %% [markdown]
# ### PREDICCIONES A NIVEL DE ARTÍCULO

# %%
ventas_tienda_art = df_venart.groupby([df_venart['fecha'].dt.date, 'item','store'])['unidades'].sum().unstack().fillna(0).reset_index()
ventas_tienda_art.columns.name = None

predicciones_TOTALES = pd.DataFrame()
j = 0
for articulo in sorted(ventas_tienda_art['item'].unique()):
    j += 1
    print(f"art: {articulo} -> {j} de 3049 -> {j/3049}")
    ventas_art = ventas_tienda_art.loc[ventas_tienda_art['item'] == articulo]
    ventas_art = ventas_art.drop(columns=['item'])
    ventas_art['fecha'] = pd.to_datetime(ventas_art['fecha'])
    rango = pd.date_range(start="2011-01-29", end="2016-04-24")
    ventas_art = pd.merge(pd.DataFrame({'fecha': rango}), ventas_art, on='fecha', how='left')
    ventas_art = ventas_art.fillna(0)
    ventas_art.set_index('fecha', inplace=True)
    ventas_art['Total Tiendas'] = ventas_art.iloc[:, 0:].sum(axis=1)
    ventas_art['evento'] = ventas_art.index.isin(df_eventos['date']) 

    for i, tienda in enumerate(tiendas_XGB):
        print(f"{i} Tienda XGB: {tienda}")
        df = ventas_art[[tienda, 'evento']].copy()
        if tienda in tiendas_XGB_24_L30:
            df = df.loc['2014-04-24':'2016-04-24']
        # Agregar más características relevantes
        df['mes'] = df.index.month
        df['dia_semana'] = df.index.weekday
    
        # Agregar los lags de 7, 30 y 365 días
        df['lag_1'] = df[tienda].shift(1)
        df['lag_7'] = df[tienda].shift(7)
        df['lag_30'] = df[tienda].shift(30)
        if tienda in tiendas_XGB_SC_L365:
            df['lag_365'] = df[tienda].shift(365)
  
        # Eliminar filas con valores nulos que surgen por los lags
        df = df.dropna()

        # Preparar los datos para XGBoost, incluyendo las nuevas características de lag
        if tienda in tiendas_XGB_SC_L365:
            X_train = df[['evento', 'mes', 'dia_semana', 'lag_1','lag_7', 'lag_30', 'lag_365']].values
        
        else:
            X_train = df[['evento', 'mes', 'dia_semana', 'lag_1','lag_7', 'lag_30']].values
         

        y_train = df[tienda].values
     

        ne = df_hp.loc[df_hp['tienda'] == tienda, 'n_estimators'].values[0]
        md = df_hp.loc[df_hp['tienda'] == tienda, 'max_depth'].values[0]
        model = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=ne,learning_rate=0.1, max_depth=md)
        model.fit(X_train, y_train)

        # Predecir los próximos 28 días después del conjunto de prueba
        future_dates = pd.date_range(start=df.index[-1] + pd.Timedelta(days=1), periods=28)
        future_eventos = pd.Series(future_dates).apply(lambda x: x in df_eventos['date'].values)
        future_mes = future_dates.month
        future_dia_semana = future_dates.weekday
    
        # Predecir los futuros 28 días (para las lags futuras se utiliza el forecast de días anteriores)
        future_lag_1 = df[tienda].shift(1).iloc[-28:].values
        future_lag_7 = df[tienda].shift(7).iloc[-28:].values
        future_lag_30 = df[tienda].shift(30).iloc[-28:].values
        if tienda in tiendas_XGB_SC_L365:
            future_lag_365 = df[tienda].shift(365).iloc[-28:].values
            X_future = np.column_stack((future_eventos, future_mes, future_dia_semana, future_lag_1, future_lag_7, future_lag_30, future_lag_365))
        else:
            X_future = np.column_stack((future_eventos, future_mes, future_dia_semana, future_lag_1, future_lag_7, future_lag_30))

        forecast_28_days = model.predict(X_future)

        # Crear DataFrame con las predicciones
        df_predicciones = pd.DataFrame({
            'Fecha': future_dates,
            'Prediccion_Ventas': forecast_28_days,
            'Tienda': tienda,
            'Articulo': articulo,
            'Modelo': 'XGBOOST'
      })

        # Almacenar las predicciones en la lista
        predicciones_TOTALES = pd.concat([predicciones_TOTALES, df_predicciones], ignore_index=True)

    for i, tienda in enumerate(tiendas_SARIMAX):  
        print(f"{i} Tienda ARM: {tienda}")
        df = ventas_art[[tienda, 'evento']].copy()
        df['evento'] = df['evento'].astype(int)

        # ENTRENO EL MODELO CON TODOS LOS DATOS
        sarimax_model = SARIMAX(df[tienda], exog=df[['evento']],
                            order=(1, 1, 1),
                            seasonal_order=(1, 1, 1, 7),
                            initialization='approximate_diffuse')
        results_sarimax = sarimax_model.fit(disp=False)

        fechas_futuras = pd.date_range(start=df.index[-1] + pd.Timedelta(days=1), periods=28)
        forecast_28_days = results_sarimax.predict(start=len(df), end=len(df) + 27, exog=pd.DataFrame({'evento': [0] * 28}))

         # Crear un DataFrame para almacenar las predicciones de cada tienda
        df_predicciones = pd.DataFrame({
            'Fecha': fechas_futuras,
            'Prediccion_Ventas': forecast_28_days,
            'Tienda': tienda,
            'Articulo': articulo,
            'Modelo': 'SARIMAX'
            })

        # Almacenar las predicciones en la lista
        predicciones_TOTALES = pd.concat([predicciones_TOTALES, df_predicciones], ignore_index=True)

predicciones_TOTALES.to_csv('Pred_uds_art.txt')
# Out:
# art: ACCESORIES_1_001 -> 1 de 3049 -> 0.00032797638570022957
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_002 -> 2 de 3049 -> 0.0006559527714004591
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_003 -> 3 de 3049 -> 0.0009839291571006887
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_004 -> 4 de 3049 -> 0.0013119055428009183
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_005 -> 5 de 3049 -> 0.0016398819285011479
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_006 -> 6 de 3049 -> 0.0019678583142013774
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_007 -> 7 de 3049 -> 0.0022958346999016072
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_008 -> 8 de 3049 -> 0.0026238110856018366
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_009 -> 9 de 3049 -> 0.0029517874713020664
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_010 -> 10 de 3049 -> 0.0032797638570022957
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_011 -> 11 de 3049 -> 0.0036077402427025255
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_012 -> 12 de 3049 -> 0.003935716628402755
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_013 -> 13 de 3049 -> 0.004263693014102984
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_014 -> 14 de 3049 -> 0.0045916693998032145
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_015 -> 15 de 3049 -> 0.004919645785503444
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_016 -> 16 de 3049 -> 0.005247622171203673
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_017 -> 17 de 3049 -> 0.0055755985569039025
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_018 -> 18 de 3049 -> 0.005903574942604133
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_019 -> 19 de 3049 -> 0.006231551328304362
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_020 -> 20 de 3049 -> 0.0065595277140045915
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_021 -> 21 de 3049 -> 0.006887504099704822
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_022 -> 22 de 3049 -> 0.007215480485405051
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_023 -> 23 de 3049 -> 0.00754345687110528
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_024 -> 24 de 3049 -> 0.00787143325680551
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_025 -> 25 de 3049 -> 0.008199409642505739
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_026 -> 26 de 3049 -> 0.008527386028205968
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_027 -> 27 de 3049 -> 0.0088553624139062
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_028 -> 28 de 3049 -> 0.009183338799606429
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_029 -> 29 de 3049 -> 0.009511315185306658
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_030 -> 30 de 3049 -> 0.009839291571006888
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_031 -> 31 de 3049 -> 0.010167267956707117
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_032 -> 32 de 3049 -> 0.010495244342407346
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_033 -> 33 de 3049 -> 0.010823220728107576
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_034 -> 34 de 3049 -> 0.011151197113807805
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_035 -> 35 de 3049 -> 0.011479173499508036
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_036 -> 36 de 3049 -> 0.011807149885208265
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_037 -> 37 de 3049 -> 0.012135126270908495
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_038 -> 38 de 3049 -> 0.012463102656608724
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_039 -> 39 de 3049 -> 0.012791079042308954
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_040 -> 40 de 3049 -> 0.013119055428009183
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_041 -> 41 de 3049 -> 0.013447031813709412
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_042 -> 42 de 3049 -> 0.013775008199409643
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_043 -> 43 de 3049 -> 0.014102984585109873
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_044 -> 44 de 3049 -> 0.014430960970810102
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_045 -> 45 de 3049 -> 0.014758937356510331
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_046 -> 46 de 3049 -> 0.01508691374221056
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_047 -> 47 de 3049 -> 0.01541489012791079
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_048 -> 48 de 3049 -> 0.01574286651361102
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_049 -> 49 de 3049 -> 0.01607084289931125
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_050 -> 50 de 3049 -> 0.016398819285011478
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_051 -> 51 de 3049 -> 0.016726795670711708
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_052 -> 52 de 3049 -> 0.017054772056411937
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_053 -> 53 de 3049 -> 0.017382748442112166
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_054 -> 54 de 3049 -> 0.0177107248278124
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_055 -> 55 de 3049 -> 0.01803870121351263
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_056 -> 56 de 3049 -> 0.018366677599212858
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_057 -> 57 de 3049 -> 0.018694653984913087
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_058 -> 58 de 3049 -> 0.019022630370613317
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_060 -> 59 de 3049 -> 0.019350606756313546
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_061 -> 60 de 3049 -> 0.019678583142013775
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_062 -> 61 de 3049 -> 0.020006559527714005
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_063 -> 62 de 3049 -> 0.020334535913414234
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_064 -> 63 de 3049 -> 0.020662512299114463
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_065 -> 64 de 3049 -> 0.020990488684814693
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_066 -> 65 de 3049 -> 0.021318465070514922
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_067 -> 66 de 3049 -> 0.02164644145621515
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_068 -> 67 de 3049 -> 0.02197441784191538
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_069 -> 68 de 3049 -> 0.02230239422761561
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_070 -> 69 de 3049 -> 0.022630370613315843
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_072 -> 70 de 3049 -> 0.022958346999016072
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_073 -> 71 de 3049 -> 0.0232863233847163
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_074 -> 72 de 3049 -> 0.02361429977041653
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_075 -> 73 de 3049 -> 0.02394227615611676
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_076 -> 74 de 3049 -> 0.02427025254181699
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_077 -> 75 de 3049 -> 0.02459822892751722
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_078 -> 76 de 3049 -> 0.02492620531321745
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_079 -> 77 de 3049 -> 0.025254181698917678
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_080 -> 78 de 3049 -> 0.025582158084617907
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_081 -> 79 de 3049 -> 0.025910134470318136
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_082 -> 80 de 3049 -> 0.026238110856018366
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_083 -> 81 de 3049 -> 0.026566087241718595
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_084 -> 82 de 3049 -> 0.026894063627418825
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_085 -> 83 de 3049 -> 0.027222040013119054
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_086 -> 84 de 3049 -> 0.027550016398819287
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_087 -> 85 de 3049 -> 0.027877992784519516
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_088 -> 86 de 3049 -> 0.028205969170219745
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_089 -> 87 de 3049 -> 0.028533945555919975
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_090 -> 88 de 3049 -> 0.028861921941620204
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_091 -> 89 de 3049 -> 0.029189898327320433
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_092 -> 90 de 3049 -> 0.029517874713020663
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_093 -> 91 de 3049 -> 0.029845851098720892
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_094 -> 92 de 3049 -> 0.03017382748442112
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_095 -> 93 de 3049 -> 0.03050180387012135
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_097 -> 94 de 3049 -> 0.03082978025582158
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_098 -> 95 de 3049 -> 0.03115775664152181
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_099 -> 96 de 3049 -> 0.03148573302722204
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_100 -> 97 de 3049 -> 0.03181370941292227
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_102 -> 98 de 3049 -> 0.0321416857986225
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_103 -> 99 de 3049 -> 0.03246966218432273
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_104 -> 100 de 3049 -> 0.032797638570022956
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_105 -> 101 de 3049 -> 0.033125614955723186
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_106 -> 102 de 3049 -> 0.033453591341423415
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_107 -> 103 de 3049 -> 0.033781567727123644
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_108 -> 104 de 3049 -> 0.034109544112823874
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_109 -> 105 de 3049 -> 0.0344375204985241
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_110 -> 106 de 3049 -> 0.03476549688422433
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_111 -> 107 de 3049 -> 0.03509347326992457
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_112 -> 108 de 3049 -> 0.0354214496556248
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_113 -> 109 de 3049 -> 0.03574942604132503
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_114 -> 110 de 3049 -> 0.03607740242702526
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_115 -> 111 de 3049 -> 0.036405378812725486
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_116 -> 112 de 3049 -> 0.036733355198425716
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_117 -> 113 de 3049 -> 0.037061331584125945
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_118 -> 114 de 3049 -> 0.037389307969826174
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_119 -> 115 de 3049 -> 0.037717284355526404
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_120 -> 116 de 3049 -> 0.03804526074122663
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_121 -> 117 de 3049 -> 0.03837323712692686
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_122 -> 118 de 3049 -> 0.03870121351262709
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_123 -> 119 de 3049 -> 0.03902918989832732
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_124 -> 120 de 3049 -> 0.03935716628402755
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_125 -> 121 de 3049 -> 0.03968514266972778
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_126 -> 122 de 3049 -> 0.04001311905542801
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_127 -> 123 de 3049 -> 0.04034109544112824
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_128 -> 124 de 3049 -> 0.04066907182682847
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_129 -> 125 de 3049 -> 0.0409970482125287
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_130 -> 126 de 3049 -> 0.04132502459822893
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_131 -> 127 de 3049 -> 0.041653000983929156
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_132 -> 128 de 3049 -> 0.041980977369629385
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_133 -> 129 de 3049 -> 0.042308953755329615
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_134 -> 130 de 3049 -> 0.042636930141029844
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_135 -> 131 de 3049 -> 0.04296490652673007
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_136 -> 132 de 3049 -> 0.0432928829124303
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_137 -> 133 de 3049 -> 0.04362085929813053
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_138 -> 134 de 3049 -> 0.04394883568383076
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_139 -> 135 de 3049 -> 0.04427681206953099
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_140 -> 136 de 3049 -> 0.04460478845523122
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_141 -> 137 de 3049 -> 0.04493276484093145
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_142 -> 138 de 3049 -> 0.045260741226631686
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_143 -> 139 de 3049 -> 0.045588717612331915
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_144 -> 140 de 3049 -> 0.045916693998032145
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_145 -> 141 de 3049 -> 0.046244670383732374
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_146 -> 142 de 3049 -> 0.0465726467694326
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: ACCESORIES_1_147 -> 143 de 3049 -> 0.04690062315513283
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# ...
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_781 -> 3003 de 3049 -> 0.9849130862577894
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_782 -> 3004 de 3049 -> 0.9852410626434897
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_783 -> 3005 de 3049 -> 0.9855690390291899
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_784 -> 3006 de 3049 -> 0.9858970154148902
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_785 -> 3007 de 3049 -> 0.9862249918005903
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_786 -> 3008 de 3049 -> 0.9865529681862906
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_787 -> 3009 de 3049 -> 0.9868809445719908
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_788 -> 3010 de 3049 -> 0.9872089209576911
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_789 -> 3011 de 3049 -> 0.9875368973433912
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_790 -> 3012 de 3049 -> 0.9878648737290915
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_791 -> 3013 de 3049 -> 0.9881928501147917
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_792 -> 3014 de 3049 -> 0.988520826500492
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_793 -> 3015 de 3049 -> 0.9888488028861921
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_794 -> 3016 de 3049 -> 0.9891767792718924
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_795 -> 3017 de 3049 -> 0.9895047556575927
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_796 -> 3018 de 3049 -> 0.9898327320432929
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_797 -> 3019 de 3049 -> 0.9901607084289931
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_798 -> 3020 de 3049 -> 0.9904886848146933
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_799 -> 3021 de 3049 -> 0.9908166612003936
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_800 -> 3022 de 3049 -> 0.9911446375860938
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_801 -> 3023 de 3049 -> 0.991472613971794
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_802 -> 3024 de 3049 -> 0.9918005903574942
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_803 -> 3025 de 3049 -> 0.9921285667431945
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_804 -> 3026 de 3049 -> 0.9924565431288948
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_805 -> 3027 de 3049 -> 0.9927845195145949
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_806 -> 3028 de 3049 -> 0.9931124959002952
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_807 -> 3029 de 3049 -> 0.9934404722859954
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_808 -> 3030 de 3049 -> 0.9937684486716957
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_809 -> 3031 de 3049 -> 0.9940964250573958
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_810 -> 3032 de 3049 -> 0.9944244014430961
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_811 -> 3033 de 3049 -> 0.9947523778287963
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_812 -> 3034 de 3049 -> 0.9950803542144966
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_813 -> 3035 de 3049 -> 0.9954083306001967
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_814 -> 3036 de 3049 -> 0.995736306985897
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_815 -> 3037 de 3049 -> 0.9960642833715972
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_816 -> 3038 de 3049 -> 0.9963922597572975
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_817 -> 3039 de 3049 -> 0.9967202361429977
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_818 -> 3040 de 3049 -> 0.9970482125286979
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_819 -> 3041 de 3049 -> 0.9973761889143982
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_820 -> 3042 de 3049 -> 0.9977041653000984
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_821 -> 3043 de 3049 -> 0.9980321416857986
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_822 -> 3044 de 3049 -> 0.9983601180714988
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_823 -> 3045 de 3049 -> 0.9986880944571991
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_824 -> 3046 de 3049 -> 0.9990160708428993
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_825 -> 3047 de 3049 -> 0.9993440472285995
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_826 -> 3048 de 3049 -> 0.9996720236142997
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury
# art: SUPERMARKET_3_827 -> 3049 de 3049 -> 1.0
# 0 Tienda XGB: Back_Bay
# 1 Tienda XGB: Yorktown
# 2 Tienda XGB: Harlem
# 3 Tienda XGB: Total Tiendas
# 4 Tienda XGB: Greenwich_Village
# 5 Tienda XGB: Queen_Village
# 6 Tienda XGB: South_End
# 7 Tienda XGB: Tribeca
# 0 Tienda ARM: Brooklyn
# 1 Tienda ARM: Midtown_Village
# 2 Tienda ARM: Roxbury

# %%
df_venart
# Out:
#               fecha  ejercicio  mes  semana store_code     category     department  \
# 0        2011-03-09       2011    3      10      BOS_1   ACCESORIES   ACCESORIES_1
# 1        2011-03-11       2011    3      10      BOS_1   ACCESORIES   ACCESORIES_1
# 2        2011-03-12       2011    3      10      BOS_1   ACCESORIES   ACCESORIES_1
# 3        2011-03-13       2011    3      10      BOS_1   ACCESORIES   ACCESORIES_1
# 4        2011-03-19       2011    3      11      BOS_1   ACCESORIES   ACCESORIES_1
# ...             ...        ...  ...     ...        ...          ...            ...
# 18550271 2016-04-03       2016    4      13      PHI_3  SUPERMARKET  SUPERMARKET_3
# 18550272 2016-04-04       2016    4      14      PHI_3  SUPERMARKET  SUPERMARKET_3
# 18550273 2016-04-05       2016    4      14      PHI_3  SUPERMARKET  SUPERMARKET_3
# 18550274 2016-04-06       2016    4      14      PHI_3  SUPERMARKET  SUPERMARKET_3
# 18550275 2016-04-09       2016    4      14      PHI_3  SUPERMARKET  SUPERMARKET_3
#
#                        item  unidades  cifra        region          store  latitud  longitud
# 0          ACCESORIES_1_002      1.00   5.28        Boston      South_End    42.34    -71.07
# 1          ACCESORIES_1_002      1.00   5.28        Boston      South_End    42.34    -71.07
# 2          ACCESORIES_1_002      1.00   5.28        Boston      South_End    42.34    -71.07
# 3          ACCESORIES_1_002      1.00   5.28        Boston      South_End    42.34    -71.07
# 4          ACCESORIES_1_002      1.00   5.28        Boston      South_End    42.34    -71.07
# ...                     ...       ...    ...           ...            ...      ...       ...
# 18550271  SUPERMARKET_3_827      1.00   1.20  Philadelphia  Queen_Village    39.94    -75.15
# 18550272  SUPERMARKET_3_827      2.00   2.40  Philadelphia  Queen_Village    39.94    -75.15
# 18550273  SUPERMARKET_3_827      3.00   3.60  Philadelphia  Queen_Village    39.94    -75.15
# 18550274  SUPERMARKET_3_827      2.00   2.40  Philadelphia  Queen_Village    39.94    -75.15
# 18550275  SUPERMARKET_3_827      1.00   1.20  Philadelphia  Queen_Village    39.94    -75.15
#
# [18550276 rows x 14 columns]

# %%
ventas_tienda = df_venart.groupby([df_venart['fecha'].dt.date,'store'])['unidades'].sum().unstack().fillna(0).reset_index()
ventas_tienda.columns.name = None
rango = pd.date_range(start="2011-01-29", end="2016-04-24")
ventas_tienda['fecha'] = pd.to_datetime(ventas_tienda['fecha'], format = '%Y-%m-%d')
ventas_tienda = pd.merge(pd.DataFrame({'fecha': rango}), ventas_tienda, on='fecha', how='left')
ventas_tienda = ventas_tienda.fillna(0)
ventas_tienda.set_index('fecha', inplace=True)
ventas_tienda['Total Tiendas'] = ventas_tienda.iloc[:, 0:].sum(axis=1)
ventas_tienda['evento'] = ventas_tienda.index.isin(df_eventos['date'])

# %%
ventas_tienda
# Out:
#             Back_Bay  Brooklyn  Greenwich_Village  Harlem  Midtown_Village  Queen_Village  \
# fecha
# 2011-01-29   3030.00   1625.00            4337.00 3494.00          2704.00        4038.00
# 2011-01-30   3006.00   1777.00            4155.00 3046.00          2194.00        4198.00
# 2011-01-31   2225.00   1386.00            2816.00 2121.00          1562.00        3317.00
# 2011-02-01   2169.00   1440.00            3051.00 2324.00          1251.00        3211.00
# 2011-02-02   1726.00   1536.00            2630.00 1942.00             2.00        2132.00
# ...              ...       ...                ...     ...              ...            ...
# 2016-04-20   3315.00   2500.00            3722.00 3691.00          3242.00        3159.00
# 2016-04-21   3380.00   2458.00            3709.00 3303.00          3324.00        3226.00
# 2016-04-22   3691.00   2628.00            4387.00 4457.00          3991.00        3828.00
# 2016-04-23   4083.00   2954.00            5577.00 5884.00          4772.00        4686.00
# 2016-04-24   3957.00   3271.00            6113.00 6082.00          4874.00        4325.00
#
#             Roxbury  South_End  Tribeca  Yorktown  Total Tiendas  evento
# fecha
# 2011-01-29  3852.00    2556.00  4739.00   2256.00       32631.00   False
# 2011-01-30  3937.00    2687.00  4827.00   1922.00       31749.00   False
# 2011-01-31  2731.00    1822.00  3785.00   2018.00       23783.00   False
# 2011-02-01  2954.00    2258.00  4232.00   2522.00       25412.00   False
# 2011-02-02  2492.00    1694.00  3817.00   1175.00       19146.00   False
# ...             ...        ...      ...       ...            ...     ...
# 2016-04-20  3384.00    2901.00  5235.00   4194.00       35343.00   False
# 2016-04-21  3446.00    2776.00  5018.00   4393.00       35033.00   False
# 2016-04-22  3902.00    3022.00  5623.00   4988.00       40517.00   False
# 2016-04-23  4483.00    3700.00  7419.00   5404.00       48962.00   False
# 2016-04-24  4292.00    4033.00  7721.00   5127.00       49795.00   False
#
# [1913 rows x 12 columns]

# %%
articulo_consulta = 'SUPERMARKET_3_090'
tienda_consulta = 'Tribeca'
ventas_articulo = df_venart[(df_venart['item'] == articulo_consulta) & (df_venart['store'] == tienda_consulta)]
ventas_articulo = ventas_articulo.groupby([ventas_articulo['fecha'].dt.date,'store'])['unidades'].sum().unstack().fillna(0).reset_index()
ventas_articulo.columns.name = None
rango = pd.date_range(start="2011-01-29", end="2016-04-24")
ventas_articulo['fecha'] = pd.to_datetime(ventas_articulo['fecha'], format = '%Y-%m-%d')
ventas_articulo = pd.merge(pd.DataFrame({'fecha': rango}), ventas_articulo, on='fecha', how='left')
ventas_articulo = ventas_articulo.fillna(0)
ventas_articulo.set_index('fecha', inplace=True)


predicciones_articulo = predicciones_TOTALES[(predicciones_TOTALES['Articulo'] == articulo_consulta) & (predicciones_TOTALES['Tienda'] == tienda_consulta)]
predicciones_articulo = predicciones_articulo.set_index('Fecha')
print (ventas_articulo)
print (predicciones_articulo)

# VISUALIZACIÓN DE PREDICCIONES
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Scatter(x=ventas_articulo.index, y=ventas_articulo[tienda_consulta], mode='lines', name='Datos históricos'))
fig.add_trace(go.Scatter(x=predicciones_articulo.index, y=predicciones_articulo['Prediccion_Ventas'], mode='lines', name='Predicciones'))      
    
# AÑADO LAS MARCAS DE LOS DÍAS FESTIVOS POR SI AYUDAN A INTERPORETAR EL MODELO
for _, evento in df_eventos.iterrows():
    evento_date = evento['date']
    evento_name = evento['event']
    fig.add_vline(x=evento_date, line=dict(color="red", width=2, dash="dash"))
    fig.add_annotation(x=evento_date, y=1, text=evento_name, showarrow=True, arrowhead=1, textangle=-90, valign="top")
  
    #fig.add_annotation(x=evento_date, y=max(ventas_articulo[tienda_consulta].max(), max(predicciones_articulo['Prediccion_Ventas'])), text=evento_name, showarrow=True, arrowhead=1, textangle=-90, valign="top")
  
    # ALGUNOS AJUSTES DE DISEÑO DE LOS GRÁFICOS
fig.update_layout(
    title= f'{tienda_consulta} Predicción Final Artículo {articulo_consulta}',
    xaxis_title='Fecha',
    yaxis_title=tienda_consulta,
    legend=dict(x=0.4, y=1.4),
    xaxis=dict(
        tickformat='%Y-%m-%d',
        tickmode='auto',
        nticks=100,  # Ajusta el número de etiquetas en el eje x
        range=['2015-05-24', '2016-05-23']  # Limita el rango de fechas
    ),
    template='plotly_white'
)

fig.show()
# Out:
#             Tribeca
# fecha
# 2011-01-29   108.00
# 2011-01-30   132.00
# 2011-01-31   102.00
# 2011-02-01   120.00
# 2011-02-02   106.00
# ...             ...
# 2016-04-20    88.00
# 2016-04-21    77.00
# 2016-04-22   141.00
# 2016-04-23   139.00
# 2016-04-24   130.00
#
# [1913 rows x 1 columns]
#             Prediccion_Ventas   Tienda           Articulo   Modelo
# Fecha
# 2016-04-25              97.88  Tribeca  SUPERMARKET_3_090  XGBOOST
# 2016-04-26              73.95  Tribeca  SUPERMARKET_3_090  XGBOOST
# 2016-04-27              81.69  Tribeca  SUPERMARKET_3_090  XGBOOST
# 2016-04-28             118.32  Tribeca  SUPERMARKET_3_090  XGBOOST
# 2016-04-29             168.73  Tribeca  SUPERMARKET_3_090  XGBOOST
# 2016-04-30             179.60  Tribeca  SUPERMARKET_3_090  XGBOOST
# 2016-05-01             123.77  Tribeca  SUPERMARKET_3_090  XGBOOST
# 2016-05-02              97.33  Tribeca  SUPERMARKET_3_090  XGBOOST
# 2016-05-03              86.46  Tribeca  SUPERMARKET_3_090  XGBOOST
# 2016-05-04              93.11  Tribeca  SUPERMARKET_3_090  XGBOOST
# 2016-05-05             116.88  Tribeca  SUPERMARKET_3_090  XGBOOST
# 2016-05-06             131.19  Tribeca  SUPERMARKET_3_090  XGBOOST
# 2016-05-07             154.74  Tribeca  SUPERMARKET_3_090  XGBOOST
# 2016-05-08             130.55  Tribeca  SUPERMARKET_3_090  XGBOOST
# 2016-05-09             100.27  Tribeca  SUPERMARKET_3_090  XGBOOST
# 2016-05-10              90.38  Tribeca  SUPERMARKET_3_090  XGBOOST
# 2016-05-11              97.79  Tribeca  SUPERMARKET_3_090  XGBOOST
# 2016-05-12              98.26  Tribeca  SUPERMARKET_3_090  XGBOOST
# 2016-05-13             136.24  Tribeca  SUPERMARKET_3_090  XGBOOST
# 2016-05-14             159.55  Tribeca  SUPERMARKET_3_090  XGBOOST
# 2016-05-15             142.48  Tribeca  SUPERMARKET_3_090  XGBOOST
# 2016-05-16             105.83  Tribeca  SUPERMARKET_3_090  XGBOOST
# 2016-05-17              84.84  Tribeca  SUPERMARKET_3_090  XGBOOST
# 2016-05-18             101.30  Tribeca  SUPERMARKET_3_090  XGBOOST
# 2016-05-19              99.45  Tribeca  SUPERMARKET_3_090  XGBOOST
# 2016-05-20             122.31  Tribeca  SUPERMARKET_3_090  XGBOOST
# 2016-05-21             177.63  Tribeca  SUPERMARKET_3_090  XGBOOST
# 2016-05-22             142.83  Tribeca  SUPERMARKET_3_090  XGBOOST

# %%
import pandas as pd
from datetime import timedelta

articulo_consulta = 'SUPERMARKET_3_090'
tienda_consulta = 'Tribeca'
ventas_articulo = df_venart[(df_venart['item'] == articulo_consulta) & (df_venart['store'] == tienda_consulta)]
ventas_articulo = ventas_articulo.groupby([ventas_articulo['fecha'].dt.date,'store'])['unidades'].sum().unstack().fillna(0).reset_index()
ventas_articulo.columns.name = None
rango = pd.date_range(start="2011-01-29", end="2016-04-24")
ventas_articulo['fecha'] = pd.to_datetime(ventas_articulo['fecha'], format = '%Y-%m-%d')
ventas_articulo = pd.merge(pd.DataFrame({'fecha': rango}), ventas_articulo, on='fecha', how='left')
ventas_articulo = ventas_articulo.fillna(0)
ventas_articulo.set_index('fecha', inplace=True)
predicciones_articulo = predicciones_TOTALES[(predicciones_TOTALES['Articulo'] == articulo_consulta) & (predicciones_TOTALES['Tienda'] == tienda_consulta)]
predicciones_articulo = predicciones_articulo.set_index('Fecha')

# Obtén la fecha máxima y calcula el rango de los últimos 365 días
fecha_maxima = predicciones_articulo.index.max()  # Última fecha de predicción
fecha_maxima = ventas_articulo.index.max() + timedelta(days=7) # Última fecha de predicción
fecha_minima = fecha_maxima - timedelta(days=365)  # 365 días atrás

# Filtra los datos de ventas y predicciones para los últimos 365 días
ventas_filtradas = ventas_articulo[tienda_consulta].loc[fecha_minima:fecha_maxima]
predicciones_filtradas = predicciones_articulo['Prediccion_Ventas'].loc[fecha_minima:fecha_maxima]
max_valor = max(ventas_filtradas.max(), predicciones_filtradas.max())

fig = go.Figure()
fig.add_trace(go.Scatter(x=ventas_filtradas.index, y=ventas_filtradas, mode='lines', name='Datos históricos'))
fig.add_trace(go.Scatter(x=predicciones_filtradas.index, y=predicciones_filtradas, mode='lines', name='Predicciones'))

# Añadir eventos
for _, evento in df_eventos.iterrows():
    evento_date = evento['date']
    evento_name = evento['event']
    fig.add_vline(x=evento_date, line=dict(color="red", width=2, dash="dash"))
    fig.add_annotation(x=evento_date, y=max_valor, text=evento_name, showarrow=True, arrowhead=1, textangle=-90, valign="top")

# Ajustes del diseño, incluyendo el límite del eje y
fig.update_layout(
    title=f'{tienda_consulta} Predicción Final Artículo {articulo_consulta}',
    xaxis_title='Fecha',
    yaxis_title=tienda_consulta,
    legend=dict(x=0.4, y=1.4),
    xaxis=dict(
        tickformat='%Y-%m-%d',
        tickmode='auto',
        nticks=100,  # Ajusta el número de etiquetas en el eje x
        range=[str(fecha_minima), str(fecha_maxima)]  # Limita el rango de fechas a los últimos 365 días
    ),
    yaxis=dict(
        range=[0, max_valor + 0.1 * max_valor]  # Aumenta un 10% para tener margen superior
    ),
    template='plotly_white'
)
fig.show()
